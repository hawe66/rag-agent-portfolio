# %% [markdown]
# # Week 2: docs and reference exploration

# %% [markdown]
# #

# %%
import os
from dotenv import load_dotenv
import langchain
import openai
from langchain.chat_models import init_chat_model

load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. model

# %% [markdown]
# ## 2. tool

# %% [markdown]
# ## 3. structured output
